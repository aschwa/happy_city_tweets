# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from geopy.geocoders import Nominatim
import math
import pandas as pd
import geopandas as gpd

# %%
df_centroids = pd.read_csv('../data/processed/city_centroids.csv', index_col='city_fips')
city_info = pd.read_csv('../data/processed/city_info.csv')
city_info = city_info[city_info.NAME !="Cleveland"]
fips_list = city_info.CityFIPS.values

# %%
#city_info.set_index('CityFIPS', inplace=True)
#@df_centroids = city_info.join(df_centroids)

# %%
m = Basemap(llcrnrlon=-119,llcrnrlat=22,urcrnrlon=-64,urcrnrlat=49,
        projection='lcc',lat_1=32,lat_2=45,lon_0=-95)

# load the shapefile, use the name 'states'
shp_file = '../data/raw/cb_2018_us_state_500k/cb_2018_us_state_500k'
m.readshapefile(shp_file, name='states', drawbounds=True)

# Get the location of each city and plot it
scale = 3

for city in df_centroids.iterrows():
    #loc = geolocator.geocode(city)
    #if city[0] in fips_list:
    x,y=m(city[1].x,city[1].y)
    ax = m.plot(x,y,marker='o',color='Red',markersize=4)

    

plt.savefig('results/25citymap.png', dpi=300)
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %%
city[1]
# Out:
# NAME       New York
# ST               NY
# POP2012     8270160
# x          -73.9314
# y            40.695
# Name: 3651000, dtype: object

# %%
m = Basemap(llcrnrlon=-119,llcrnrlat=22,urcrnrlon=-64,urcrnrlat=49,
        projection='lcc',lat_1=32,lat_2=45,lon_0=-95)

# load the shapefile, use the name 'states'
shp_file = '../data/raw/cb_2018_us_state_500k/cb_2018_us_state_500k'
m.readshapefile(shp_file, name='states', drawbounds=True)

# Get the location of each city and plot it
scale = 3

for city in df_centroids.iterrows():
    #loc = geolocator.geocode(city)
    if city[1].NAME == "San Francisco":
        x,y=m(city[1].x,city[1].y)
        ax = m.plot(x,y,marker='o',color='Red',markersize=4)

    

plt.savefig('results/sf_map.png', dpi=300)
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
